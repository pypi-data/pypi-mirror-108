# %% [markdown]
# # Timestep options
#
# - for perceived color and energy and mixing
# - can also for profile diagrams but need a lot of profiles

# %%
# Use interactive matplotlib plotting
# %matplotlib notebook

import matplotlib as plt
import mesaPlot as mp

EXAMPLE_DIR = "../../tulips/MESA_DIR_EXAMPLE/"

m = mp.MESA() # Create MESA object
m.loadHistory(filename_in=EXAMPLE_DIR + 'history.data')

# %%
# # Use LaTeX in the plots

col_w = 3.5    # Figure width in inches, columnswidth
text_w = 7.25 # Full page figure width
plt.rcParams.update({
    'figure.figsize': (col_w, col_w/(4/3.)),     # 4:3 aspect ratio
    'font.size' : 11,                   # Set font size to 11pt
    'axes.labelsize': 11,               # -> axis labels
    'legend.fontsize': 9,              # -> legends
    'font.family': 'lmodern',
    'text.usetex': True,
    'text.latex.preamble': (            # LaTeX preamble
        r'\usepackage{lmodern}'
        # ... more packages if needed
    ),
    'figure.dpi': 200,
})

import warnings
warnings.filterwarnings("ignore")

# %%
import tulips 

tulips.perceived_color(m, time_ind=0)
# Out:
# <img src="data:image/png;base64,..." width="549.6">
# (<Figure size 550x400 with 2 Axes>,
#  <AxesSubplot:xlabel='Radius$ \\,[\\rm{R}_\\odot]$', ylabel='Radius$ \\,[\\rm{R}_\\odot]$'>)

# %%
tulips.tulips
# Out:
# <module 'tulips.tulips' from 'C:\\Users\\ilsed\\anaconda3\\lib\\site-packages\\astro_tulips-0.2.1-py3.8.egg\\tulips\\tulips.py'>
